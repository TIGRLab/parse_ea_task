# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)

# %%
#reads in log file and subtracts the initial TRs/MRI startup time
def read_in_logfile(path):
    log_file=pd.read_csv(path, sep='\t', skiprows=3)

    time_to_subtract=int(log_file.Duration[log_file.Code=='MRI_start'])

    log_file.Time=log_file.Time-time_to_subtract #subtracts mri start times from all onset times
    
    return log_file

#Grabs the starts of blocks and returns rows for them
def get_blocks(log,vid_info):
    #identifies the video trial types (as opposed to button press events etc)
    mask = ["vid" in log['Code'][i] for i in range(0,log.shape[0])]
    
    #creates the dataframe with onset times and event types
    df = pd.DataFrame({'onset':log.loc[mask]['Time'], 
                  'trial_type':log.loc[mask]['Event Type'], 
                  'movie_name':log.loc[mask]['Code']})
        
    #adds trial type info
    df['trial_type']=df['movie_name'].apply(lambda x: "circle_block" if "cvid" in x else "EA_block")

    #add durations and convert them into the units here? 10000ths of seconds
    df['duration']=df['movie_name'].apply(lambda x: int(vid_info[x]['duration'])*10000 if x in vid_info else "n/a")

    #adds names of stim_files, according to the vid_info spreadsheet
    df['stim_file']=df['movie_name'].apply(lambda x: vid_info[x]['stim_file'] if x in vid_info else "n/a") 
    
    #adds an end column to the beginning of blocks (it's useful for processing but will remove later)
    df['end']=df['onset']+df['duration']

        
    return(df)

#grabs stimulus metadata
def format_vid_info(vid):
    vid.columns = map(str.lower, vid.columns)
    vid = vid.rename(index={0:"stim_file", 1:"duration"}) #grabs the file name and the durations from the info file
    vid = vid.to_dict()
    return(vid)

#Reads in gold standard answers
def read_in_standard(timing_path):
    df = pd.read_csv(timing_path).astype(str)
    df.columns = map(str.lower, df.columns)
    df_dict = df.drop([0,0]).reset_index(drop=True).to_dict(orient='list') #drops the video name
    return(df_dict)

#grabs gold standards as a series
def get_series_standard(gold_standard, block_name):
    
    return([float(x) for x in ratings_dict[block_name] if x != 'nan'])

#grabs partcipant ratings
def get_ratings(log):
    
    rating_mask = ["rating" in log['Code'][i] for i in range(0,log.shape[0])]  

    #So this grabs from the stim row and not the button press row, but there's like 50 10000ths of a second difference so i feel fine doing that. otherwise it creates risk for other errors if the sheets are weird.
    #gives the time and value of the partiicipant rating
    df = pd.DataFrame({'onset':log['Time'].loc[rating_mask].values, 'participant_value':log.loc[rating_mask]['Code'].values, 'event_type':'button_press', 'duration':0})    
   
    #this pretty much fixes it except for the vid_thing - one thing I could do is just get rid of the vid_ rows!! TODO later.
    
    #gets rating substring from participant numbers
    df['participant_value'] = df['participant_value'].str.strip().str[-1]
    
    return(df)

#combines the block rows with the ratings rows and sorts them
def combine_dfs(blocks,ratings):
    combo=blocks.append(ratings).sort_values("onset").reset_index(drop=True)

    mask = pd.notnull(combo['trial_type'])

    combo['rating_duration']=combo['onset'].shift(-1)-combo['onset'].where(mask==False) 

    block_start_locs=combo[mask].index.values

   
    #TODO: fix this lol
    #this ends up not assigning a value for the final button press - there must be a more elegant way to do all this
    for i in range(len(block_start_locs)):
        if block_start_locs[i] != 0:
            #maybe i should calculate these vars separately for clarity
            combo.rating_duration[block_start_locs[i]-1]=combo.end[block_start_locs[i-1]] - combo.onset[block_start_locs[i]-1]

            
#adds rows that contain the 5 second at the beginning default value
    for i in block_start_locs:
            new_row={'onset':combo.onset[i],
            'rating_duration':combo.onset[i+1] - combo.onset[i],
            'event_type':'default_rating',
            'duration':0,
            'participant_value':5}
            combo=combo.append(new_row,ignore_index=True)
        
    combo=combo.sort_values("onset").reset_index(drop=True)

    return(combo)


#calculates pearsons r by comparing participant ratings w a gold standard 
def block_scores(ratings_dict,combo):
    list_of_rows=[]
    summary_vals = {}
    mask = pd.notnull(combo['trial_type']) #selects the beginning of trials/trial headers #i feel like im recalculating that in lots of places, seems bad maybe
    block_start_locs=combo[mask].index.values #i could just append the end to that
    block_start_locs= np.append(block_start_locs, combo.tail(1).index.values, axis=None)

    for idx in range(1, len(block_start_locs)):
            #df['trial_type']=df['movie_name'].apply(lambda x: "circle_block" if "cvid" in x else "EA_block")

        block_start=combo.onset[block_start_locs[idx-1]]
        block_end=combo.end[block_start_locs[idx-1]]

        #selects the rows between the start and the end that contain button presses
        #should just change this to select the rows, idk why not lol

        block = combo.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.event_type)]#between is inclusive by default
        block_name=combo.movie_name.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.movie_name)].reset_index(drop=True).astype(str).get(0)

        ###############################################################################################
        gold=get_series_standard(ratings_dict,block_name)

        if "cvid" in block_name:
            interval = np.arange(combo.onset[block_start_locs[idx-1]], combo.end[block_start_locs[idx-1]],step=40000) #AAA oh no this only applies to the vid not the cvid (put a conditional here)
        else:
            interval = np.arange(combo.onset[block_start_locs[idx-1]], combo.end[block_start_locs[idx-1]],step=20000) #AAA oh no this only applies to the vid not the cvid (put a conditional here)



        #todo: remove print statements lol, turn them into logger things.

        if len(gold) < len(interval):
            interval=interval[:len(gold)]
            print("warning:gold standard is shorter than the number of pt ratings, pt ratings truncated", block_name)
            #todo: insert a warning that the participant ratings were truncated
            #also this doesnt account for a situation where there are less ratings than the gold standard
            #which could absolutely be a thing if the task was truncated
            #gold.extend([gold[-1]]*(len(interval)-len(gold)))

        if len(interval) < len(gold):
            gold=gold[:len(interval)]
            print("warning:number of pt ratings is shorter than the number of gold std,gold std truncated", block_name)
            #todo: insert a warning that the participant ratings were truncated            

        interval=np.append(interval, block_end) #this is to append for the remaining fraction of a second (so that the loop goes to the end i guess...)- maybe i dont need to do this

        #why is this not doing what it is supposed to do.
        #these ifs are NOT working
        two_s_avg=[]
        for x in range(len(interval)-1):
            start=interval[x]
            end=interval[x+1]
            #things that start within the time interval plus the one that starts during the time interval
            sub_block= block[block['onset'].between(start,end) | block['onset'].between(start,end).shift(-1)]
            block_length=end-start
            if len(sub_block) !=0: 
                ratings=[]
                last_val=sub_block.participant_value.iloc[[-1]]
                for index, row in sub_block.iterrows():
                    #for rows that are in the thing
                    if (row.onset < start): #and (row.onset+row.duration)>start: #what's the best order to do these conditionals in?
                        #if (row.onset+row.duration)>start: # this is just to be safe i guess, gonna see what happens if i comment it out
                        numerator=(row.onset+row.rating_duration)-start
                    else:#if row.onset>=start and row.onset<end: #ooo should i do row.onset<end for everything??
                        if (row.onset+row.rating_duration) <= end:
                            numerator=row.rating_duration
                        elif (row.onset+row.rating_duration) > end: 
                            numerator = end - row.onset
                        else:
                            numerator=9999999
                    last_row=row.participant_value
                    #okay so i want to change this to actually create the beginnings of an important row in our df!
                    ratings.append({'start':start,'end':end,'row_time':row.rating_duration, 'row_start': row.onset, 'block_length':block_length,'rating':row.participant_value, 'time_held':numerator})#, 'start': start, 'end':end})
                    nums=[float(d['rating']) for d in ratings]
                    times=[float(d['time_held'])/block_length for d in ratings]
                    avg=np.sum(np.multiply(nums,times))
            else:
                avg=last_row

            #okay so i want to change this to actually create the beginnings of an important row in our df!
            two_s_avg.append(float(avg))
            #list_of_rows.append({'event_type':"two_sec_avg",'block_name':block_name, 'participant_value':float(avg),'onset':start,'duration':end-start, 'gold_std': gold[x]})
            list_of_rows.append({'event_type':"running_avg", 'participant_value':float(avg),'onset':start,'duration':end-start, 'gold_std': gold[x]})
            #removed block_name from above
            
        n_button_press=len(block[block.event_type=='button_press'].index)
        print(n_button_press)
        block_score=np.corrcoef(gold,two_s_avg)[1][0] 
        key=str(block_name)
        summary_vals.update({key:{'n_button_press':int(n_button_press),'block_score':block_score,'onset':block_start,'duration':block_end-block_start}})
        #summary_vals.append(block_name:{'block_score':block_score,'block_name':block_name,'onset':block_start,'duration':block_end-block_start}) #i can probably not recalculate duration, just gotta remember how
    return(list_of_rows,summary_vals)

# %%
#Reads in the log, skipping the first three preamble lines

log = read_in_logfile('SPN01_CMH_0004-UCLAEmpAcc_part3.log')
vid_in = pd.read_csv('EA-vid-lengths.csv')

vid_info = format_vid_info(vid_in)
blocks = get_blocks(log, vid_info)
ratings = get_ratings(log)

#add the ratings and the block values together, then sort them and make the index numbers sequential
combo=combine_dfs(blocks,ratings)

ratings_dict= read_in_standard('EA-timing.csv')

two_s_chunks,scores= block_scores(ratings_dict,combo) #okay so i need to fix the naming here 

combo['block_score']=np.nan
combo['n_button_press']=np.nan

#combo.ix[pd.notnull(combo.trial_type), 'block_score']=

#df[df.index.isin(a_list) & df.a_col.isnull()]

combo = combo.append(two_s_chunks).sort_values("onset").reset_index(drop=True) #this needs to be fixed etc #need to sort according to name too...

test = combo.ix[pd.notnull(combo.stim_file)]

for index, row in test.iterrows():
    combo.block_score.ix[index]=scores[row['movie_name']]['block_score']
    combo.n_button_press.ix[index]=scores[row['movie_name']]['n_button_press']
    combo.event_type.ix[index]='block_summary'
   
    
cols=['onset', 'duration','trial_type','event_type','participant_value','gold_std','block_score','n_button_press', 'stim_file']
combo=combo[cols]

combo['onset']=combo.onset/10000.0
combo.duration=combo.duration/10000.0
combo.stim_file=combo.stim_file.ffill(axis=0)


combo

#TODO NEXT: put into a script yay!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#NOTE" 
#ok so tomorrow ive gotta figure out that error :( ) it occurs with 0004 part 2

#I don't think the weighted average is being calculated correctly... -nvm it is! yay!


#to do: convert to seconds, subtract the correct time from everything, check JV's code to see what he did and copy his time subtracting, bring stim_file down to all rows within a trial
# Out:
# /mnt/tigrlab/archive/code/python_2.7.13_packages_01/lib/python2.7/site-packages/ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /mnt/tigrlab/archive/code/python_2.7.13_packages_01/lib/python2.7/site-packages/ipykernel_launcher.py:121: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 6
# 14
# 3
# 18
# 3
#         onset  duration    trial_type      event_type participant_value  \
# 0     13.1560     119.0      EA_block   block_summary               NaN
# 1     13.1560       0.0           NaN  default_rating                 5
# 2     13.1560       2.0           NaN     running_avg                 5
# 3     15.1560       2.0           NaN     running_avg                 5
# 4     17.1560       2.0           NaN     running_avg                 5
# 5     19.1560       2.0           NaN     running_avg                 5
# 6     21.1560       2.0           NaN     running_avg                 5
# 7     23.1560       2.0           NaN     running_avg             4.341
# 8     23.8380       0.0           NaN    button_press                 4
# 9     25.1560       2.0           NaN     running_avg                 4
# 10    27.1560       2.0           NaN     running_avg           3.38045
# 11    27.9169       0.0           NaN    button_press                 3
# 12    29.1560       2.0           NaN     running_avg                 3
# 13    31.1560       2.0           NaN     running_avg                 3
# 14    33.1560       2.0           NaN     running_avg                 3
# 15    35.1560       2.0           NaN     running_avg                 3
# 16    37.1560       2.0           NaN     running_avg                 3
# 17    39.1560       2.0           NaN     running_avg                 3
# 18    41.1560       2.0           NaN     running_avg                 3
# 19    43.1560       2.0           NaN     running_avg                 3
# 20    45.1560       2.0           NaN     running_avg                 3
# 21    47.1560       2.0           NaN     running_avg                 3
# 22    49.1560       2.0           NaN     running_avg                 3
# 23    51.1560       2.0           NaN     running_avg                 3
# 24    53.1560       2.0           NaN     running_avg                 3
# 25    55.1560       2.0           NaN     running_avg                 3
# 26    57.1560       2.0           NaN     running_avg                 3
# 27    59.1560       2.0           NaN     running_avg                 3
# 28    61.1560       2.0           NaN     running_avg                 3
# 29    63.1560       2.0           NaN     running_avg                 3
# 30    65.1560       2.0           NaN     running_avg                 3
# 31    67.1560       2.0           NaN     running_avg                 3
# 32    69.1560       2.0           NaN     running_avg                 3
# 33    71.1560       2.0           NaN     running_avg                 3
# 34    73.1560       2.0           NaN     running_avg                 3
# 35    75.1560       2.0           NaN     running_avg             2.369
# 36    75.8940       0.0           NaN    button_press                 2
# 37    77.1560       2.0           NaN     running_avg                 2
# 38    79.1560       2.0           NaN     running_avg                 2
# 39    81.1560       2.0           NaN     running_avg                 2
# 40    83.1560       2.0           NaN     running_avg                 2
# 41    85.1560       2.0           NaN     running_avg                 2
# 42    87.1560       2.0           NaN     running_avg                 2
# 43    89.1560       2.0           NaN     running_avg                 2
# 44    91.1560       2.0           NaN     running_avg                 2
# 45    93.1560       2.0           NaN     running_avg                 2
# 46    95.1560       2.0           NaN     running_avg                 2
# 47    97.1560       2.0           NaN     running_avg                 2
# 48    99.1560       2.0           NaN     running_avg                 2
# 49   101.1560       2.0           NaN     running_avg                 2
# 50   103.1560       2.0           NaN     running_avg                 2
# 51   105.1560       2.0           NaN     running_avg                 2
# 52   107.1560       2.0           NaN     running_avg                 2
# 53   109.1560       2.0           NaN     running_avg                 2
# 54   111.1560       2.0           NaN     running_avg                 2
# 55   113.1560       2.0           NaN     running_avg           1.35085
# 56   113.8577       0.0           NaN    button_press                 1
# 57   115.1560       2.0           NaN     running_avg            1.5375
# 58   116.0810       0.0           NaN    button_press                 2
# 59   117.1560       2.0           NaN     running_avg                 2
# 60   119.1560       2.0           NaN     running_avg                 2
# 61   121.1560       2.0           NaN     running_avg           1.77245
# 62   122.7009       0.0           NaN    button_press                 1
# 63   123.1560       2.0           NaN     running_avg                 1
# 64   125.1560       2.0           NaN     running_avg                 1
# 65   127.1560       2.0           NaN     running_avg                 1
# 66   129.1560       2.0           NaN     running_avg                 1
# 67   131.1560       1.0           NaN     running_avg                 1
# 68   137.3615      40.0  circle_block   block_summary               NaN
# 69   137.3615       0.0           NaN  default_rating                 5
# 70   137.3615       4.0           NaN     running_avg           5.63105
# 71   138.8158       0.0           NaN    button_press                 6
# 72   141.3400       0.0           NaN    button_press                 5
# 73   141.3615       4.0           NaN     running_avg                 5
# 74   145.3615       4.0           NaN     running_avg           6.49902
# 75   146.1712       0.0           NaN    button_press                 6
# 76   146.5557       0.0           NaN    button_press                 7
# 77   149.3615       4.0           NaN     running_avg            7.8113
# 78   150.1163       0.0           NaN    button_press                 8
# 79   153.3615       4.0           NaN     running_avg            8.7038
# 80   154.5463       0.0           NaN    button_press                 9
# 81   157.3615       4.0           NaN     running_avg            7.8408
# 82   158.6586       0.0           NaN    button_press                 8
# 83   159.4276       0.0           NaN    button_press                 7
# 84   161.3615       4.0           NaN     running_avg            5.7841
# 85   162.5703       0.0           NaN    button_press                 6
# 86   163.2891       0.0           NaN    button_press                 5
# 87   165.3615       4.0           NaN     running_avg           5.82957
# 88   166.0641       0.0           NaN    button_press                 6
# 89   169.3406       0.0           NaN    button_press                 7
# 90   169.3615       4.0           NaN     running_avg                 7
# 91   173.3615       4.0           NaN     running_avg             8.294
# 92   174.0714       0.0           NaN    button_press                 8
# 93   175.4756       0.0           NaN    button_press                 9
# 94   182.4967       2.0           NaN     running_avg            1.0334
# 95   182.4967       0.0           NaN  default_rating                 5
# 96   182.4967     179.0      EA_block   block_summary               NaN
# 97   182.5134       0.0           NaN    button_press                 1
# 98   184.4967       2.0           NaN     running_avg                 1
# 99   186.4967       2.0           NaN     running_avg                 1
# 100  188.4967       2.0           NaN     running_avg                 1
# 101  190.4967       2.0           NaN     running_avg                 1
# 102  192.4967       2.0           NaN     running_avg                 1
# 103  194.4967       2.0           NaN     running_avg                 1
# 104  196.4967       2.0           NaN     running_avg                 1
# 105  198.4967       2.0           NaN     running_avg                 1
# 106  200.4967       2.0           NaN     running_avg                 1
# 107  202.4967       2.0           NaN     running_avg                 1
# 108  204.4967       2.0           NaN     running_avg                 1
# 109  206.4967       2.0           NaN     running_avg                 1
# 110  208.4967       2.0           NaN     running_avg                 1
# 111  210.4967       2.0           NaN     running_avg                 1
# 112  212.4967       2.0           NaN     running_avg                 1
# 113  214.4967       2.0           NaN     running_avg                 1
# 114  216.4967       2.0           NaN     running_avg                 1
# 115  218.4967       2.0           NaN     running_avg                 1
# 116  220.4967       2.0           NaN     running_avg                 1
# 117  222.4967       2.0           NaN     running_avg                 1
# 118  224.4967       2.0           NaN     running_avg                 1
# 119  226.4967       2.0           NaN     running_avg                 1
# 120  228.4967       2.0           NaN     running_avg                 1
# 121  230.4967       2.0           NaN     running_avg                 1
# 122  232.4967       2.0           NaN     running_avg                 1
# 123  234.4967       2.0           NaN     running_avg                 1
# 124  236.4967       2.0           NaN     running_avg                 1
# 125  238.4967       2.0           NaN     running_avg                 1
# 126  240.4967       2.0           NaN     running_avg                 1
# 127  242.4967       2.0           NaN     running_avg                 1
# 128  244.4967       2.0           NaN     running_avg                 1
# 129  246.4967       2.0           NaN     running_avg                 1
# 130  248.4967       2.0           NaN     running_avg           2.54255
# 131  249.1631       0.0           NaN    button_press                 4
# 193  367.8854       0.0           NaN    button_press                 6
# 194  370.6985       4.0           NaN     running_avg           5.06937
# 195  371.3792       0.0           NaN    button_press                 5
# 196  374.3381       0.0           NaN    button_press                 4
# 197  374.6557       0.0           NaN    button_press                 3
# 198  374.6985       4.0           NaN     running_avg           1.15413
# 199  374.8897       0.0           NaN    button_press                 2
# 200  375.1238       0.0           NaN    button_press                 1
# 201  375.3244       0.0           NaN    button_press                 1
# 202  378.6985       4.0           NaN     running_avg           2.91978
# 203  378.7179       0.0           NaN    button_press                 2
# 204  379.2695       0.0           NaN    button_press                 3
# 205  382.4290       0.0           NaN    button_press                 4
# 206  382.6985       4.0           NaN     running_avg           5.83385
# 207  382.8971       0.0           NaN    button_press                 5
# 208  383.1645       0.0           NaN    button_press                 6
# 209  386.6985       4.0           NaN     running_avg           5.05682
# 210  386.9258       0.0           NaN    button_press                 5
# 211  390.6985       4.0           NaN     running_avg            5.8315
# 212  391.3725       0.0           NaN    button_press                 6
# 213  394.6985       4.0           NaN     running_avg           7.59433
# 214  395.3678       0.0           NaN    button_press                 7
# 215  395.6519       0.0           NaN    button_press                 8
# 216  398.6985       4.0           NaN     running_avg           8.83805
# 217  399.3463       0.0           NaN    button_press                 9
# 218  402.6985       4.0           NaN     running_avg                 9
# 219  411.8505       2.0           NaN     running_avg            3.0166
# 220  411.8505     130.0      EA_block   block_summary               NaN
# 221  411.8505       0.0           NaN  default_rating                 5
# 222  411.8671       0.0           NaN    button_press                 3
# 223  413.8505       2.0           NaN     running_avg                 3
# 224  415.8505       2.0           NaN     running_avg                 3
# 225  417.8505       2.0           NaN     running_avg                 3
# 226  419.8505       2.0           NaN     running_avg                 3
# 227  421.8505       2.0           NaN     running_avg                 3
# 228  423.8505       2.0           NaN     running_avg           3.53065
# 229  424.7892       0.0           NaN    button_press                 4
# 230  425.8505       2.0           NaN     running_avg                 4
# 231  427.8505       2.0           NaN     running_avg            3.6676
# 232  429.1857       0.0           NaN    button_press                 3
# 233  429.8505       2.0           NaN     running_avg                 3
# 234  431.8505       2.0           NaN     running_avg                 3
# 235  433.8505       2.0           NaN     running_avg                 3
# 236  435.8505       2.0           NaN     running_avg                 3
# 237  437.8505       2.0           NaN     running_avg                 3
# 238  439.8505       2.0           NaN     running_avg                 3
# 239  441.8505       2.0           NaN     running_avg                 3
# 240  443.8505       2.0           NaN     running_avg                 3
# 241  445.8505       2.0           NaN     running_avg                 3
# 242  447.8505       2.0           NaN     running_avg                 3
# 243  449.8505       2.0           NaN     running_avg                 3
# 244  451.8505       2.0           NaN     running_avg                 3
# 245  453.8505       2.0           NaN     running_avg                 3
# 246  455.8505       2.0           NaN     running_avg                 3
# 247  457.8505       2.0           NaN     running_avg                 3
# 248  458.0723       0.0           NaN    button_press                 2
# 249  459.8505       2.0           NaN     running_avg                 3
# 250  461.8505       2.0           NaN     running_avg                 3
# 251  463.8505       2.0           NaN     running_avg                 3
# 252  465.8505       2.0           NaN     running_avg                 3
# 253  467.8505       2.0           NaN     running_avg                 3
# 254  469.8505       2.0           NaN     running_avg                 3
# 255  471.8505       2.0           NaN     running_avg                 3
# 256  473.8505       2.0           NaN     running_avg                 3
# 257  475.8505       2.0           NaN     running_avg                 3
# 258  477.8505       2.0           NaN     running_avg                 3
# 259  479.8505       2.0           NaN     running_avg                 3
# 260  481.8505       2.0           NaN     running_avg                 3
# 261  483.8505       2.0           NaN     running_avg                 3
# 262  485.8505       2.0           NaN     running_avg                 3
# 263  487.8505       2.0           NaN     running_avg                 3
# 264  489.8505       2.0           NaN     running_avg                 3
# 265  491.8505       2.0           NaN     running_avg                 3
# 266  493.8505       2.0           NaN     running_avg                 3
# 267  495.8505       2.0           NaN     running_avg                 3
# 268  497.8505       2.0           NaN     running_avg                 3
# 269  499.8505       2.0           NaN     running_avg                 3
# 270  501.8505       2.0           NaN     running_avg                 3
# 271  503.8505       2.0           NaN     running_avg                 3
# 272  505.8505       2.0           NaN     running_avg                 3
# 273  507.8505       2.0           NaN     running_avg                 3
# 274  509.8505       2.0           NaN     running_avg                 3
# 275  511.8505       2.0           NaN     running_avg                 3
# 276  513.8505       2.0           NaN     running_avg                 3
# 277  515.8505       2.0           NaN     running_avg                 3
# 278  517.8505       2.0           NaN     running_avg                 3
# 279  519.8505       2.0           NaN     running_avg                 3
# 280  521.8505       2.0           NaN     running_avg                 3
# 281  523.8505       2.0           NaN     running_avg                 3
# 282  525.8505       2.0           NaN     running_avg                 3
# 283  527.8505       2.0           NaN     running_avg                 3
# 284  529.8505       2.0           NaN     running_avg                 3
# 285  531.8505       2.0           NaN     running_avg                 3
# 286  533.8505       2.0           NaN     running_avg                 3
# 287  535.8505       2.0           NaN     running_avg                 3
# 288  537.8505       2.0           NaN     running_avg                 3
# 289  539.8505       2.0           NaN     running_avg                 3
#
#      gold_std  block_score  n_button_press   stim_file
# 0         NaN     0.797046             6.0    HR_1_sad
# 1         NaN          NaN             NaN    HR_1_sad
# 2      5.0000          NaN             NaN    HR_1_sad
# 3      5.0000          NaN             NaN    HR_1_sad
# 4      5.0000          NaN             NaN    HR_1_sad
# 5      5.0000          NaN             NaN    HR_1_sad
# 6      5.0000          NaN             NaN    HR_1_sad
# 7      5.0000          NaN             NaN    HR_1_sad
# 8         NaN          NaN             NaN    HR_1_sad
# 9      3.5855          NaN             NaN    HR_1_sad
# 10     3.0000          NaN             NaN    HR_1_sad
# 11        NaN          NaN             NaN    HR_1_sad
# 12     3.0000          NaN             NaN    HR_1_sad
# 13     3.0000          NaN             NaN    HR_1_sad
# 14     3.0000          NaN             NaN    HR_1_sad
# 15     3.0000          NaN             NaN    HR_1_sad
# 16     2.6085          NaN             NaN    HR_1_sad
# 17     2.0000          NaN             NaN    HR_1_sad
# 18     2.0000          NaN             NaN    HR_1_sad
# 19     2.0000          NaN             NaN    HR_1_sad
# 20     2.0000          NaN             NaN    HR_1_sad
# 21     2.0000          NaN             NaN    HR_1_sad
# 22     2.0000          NaN             NaN    HR_1_sad
# 23     2.0000          NaN             NaN    HR_1_sad
# 24     2.0000          NaN             NaN    HR_1_sad
# 25     2.0000          NaN             NaN    HR_1_sad
# 283    5.0000          NaN             NaN  DH_6_anger
# 284    5.0000          NaN             NaN  DH_6_anger
# 285    4.9720          NaN             NaN  DH_6_anger
# 286    4.0000          NaN             NaN  DH_6_anger
# 287    4.0000          NaN             NaN  DH_6_anger
# 288    4.0000          NaN             NaN  DH_6_anger
# 289    4.0000          NaN             NaN  DH_6_anger

# %%
asd = combo.ix[combo.trial_type=="EA_block"]

for index, row in asd.iterrows():
    print(sub_id,asd.stim_file.ix[index],asd.block_score.ix[index], log_head)
# Out:
# ('SPN01_MRC_0074_01_01', 'HR_1_sad', 0.79704553381765264, '/archive/data/SPINS/data/RESOURCES/SPN01_MRC_0074_01_01/BEHAV/SPN01_MRC_0068_01_01_BEHAV/archive')
# ('SPN01_MRC_0074_01_01', 'TA_6_anger', -0.90016010886420683, '/archive/data/SPINS/data/RESOURCES/SPN01_MRC_0074_01_01/BEHAV/SPN01_MRC_0068_01_01_BEHAV/archive')
# ('SPN01_MRC_0074_01_01', 'DH_6_anger', 0.1800457912844203, '/archive/data/SPINS/data/RESOURCES/SPN01_MRC_0074_01_01/BEHAV/SPN01_MRC_0068_01_01_BEHAV/archive')

# %%
#i'm wondering if i should maybe think more carefully about my architecture here in terms of what i need to calculate where.might try to refine this.

# %%
combo.iloc[45:62]

idx=1
block_name=combo.movie_name.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.movie_name)].astype(str).get(0) 
block_name
# Out:
# 'vid_4'

# %%
[gold[-1]]*(len(interval)-len(gold))
# Out:
# [7.0, 7.0, 7.0]

# %%
np.corrcoef(gold,two_s_avg)[1][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-a5064a50085b> in <module>()
# ----> 1 np.corrcoef(gold,two_s_avg)[1][0]
#
# NameError: name 'gold' is not defined

# %%
#ratings,scores=block_scores(ratings_dict,combo)
combo.tail(1).index.values
# Out:
# array([102])

# %%
combo.sort_values(by=['onset', 'event_type'])

#combo.stim_file=combo.stim_file.ffill(axis=0)
# Out:
#         onset  duration    trial_type      event_type participant_value  \
# 0     13.1560     119.0      EA_block   block_summary               NaN
# 1     13.1560       0.0           NaN  default_rating                 5
# 2     13.1560       2.0           NaN     running_avg                 5
# 3     15.1560       2.0           NaN     running_avg                 5
# 4     17.1560       2.0           NaN     running_avg                 5
# 5     19.1560       2.0           NaN     running_avg                 5
# 6     21.1560       2.0           NaN     running_avg                 5
# 7     23.1560       2.0           NaN     running_avg             4.341
# 8     23.8380       0.0           NaN    button_press                 4
# 9     25.1560       2.0           NaN     running_avg                 4
# 10    27.1560       2.0           NaN     running_avg           3.38045
# 11    27.9169       0.0           NaN    button_press                 3
# 12    29.1560       2.0           NaN     running_avg                 3
# 13    31.1560       2.0           NaN     running_avg                 3
# 14    33.1560       2.0           NaN     running_avg                 3
# 15    35.1560       2.0           NaN     running_avg                 3
# 16    37.1560       2.0           NaN     running_avg                 3
# 17    39.1560       2.0           NaN     running_avg                 3
# 18    41.1560       2.0           NaN     running_avg                 3
# 19    43.1560       2.0           NaN     running_avg                 3
# 20    45.1560       2.0           NaN     running_avg                 3
# 21    47.1560       2.0           NaN     running_avg                 3
# 22    49.1560       2.0           NaN     running_avg                 3
# 23    51.1560       2.0           NaN     running_avg                 3
# 24    53.1560       2.0           NaN     running_avg                 3
# 25    55.1560       2.0           NaN     running_avg                 3
# 26    57.1560       2.0           NaN     running_avg                 3
# 27    59.1560       2.0           NaN     running_avg                 3
# 28    61.1560       2.0           NaN     running_avg                 3
# 29    63.1560       2.0           NaN     running_avg                 3
# 30    65.1560       2.0           NaN     running_avg                 3
# 31    67.1560       2.0           NaN     running_avg                 3
# 32    69.1560       2.0           NaN     running_avg                 3
# 33    71.1560       2.0           NaN     running_avg                 3
# 34    73.1560       2.0           NaN     running_avg                 3
# 35    75.1560       2.0           NaN     running_avg             2.369
# 36    75.8940       0.0           NaN    button_press                 2
# 37    77.1560       2.0           NaN     running_avg                 2
# 38    79.1560       2.0           NaN     running_avg                 2
# 39    81.1560       2.0           NaN     running_avg                 2
# 40    83.1560       2.0           NaN     running_avg                 2
# 41    85.1560       2.0           NaN     running_avg                 2
# 42    87.1560       2.0           NaN     running_avg                 2
# 43    89.1560       2.0           NaN     running_avg                 2
# 44    91.1560       2.0           NaN     running_avg                 2
# 45    93.1560       2.0           NaN     running_avg                 2
# 46    95.1560       2.0           NaN     running_avg                 2
# 47    97.1560       2.0           NaN     running_avg                 2
# 48    99.1560       2.0           NaN     running_avg                 2
# 49   101.1560       2.0           NaN     running_avg                 2
# 50   103.1560       2.0           NaN     running_avg                 2
# 51   105.1560       2.0           NaN     running_avg                 2
# 52   107.1560       2.0           NaN     running_avg                 2
# 53   109.1560       2.0           NaN     running_avg                 2
# 54   111.1560       2.0           NaN     running_avg                 2
# 55   113.1560       2.0           NaN     running_avg           1.35085
# 56   113.8577       0.0           NaN    button_press                 1
# 57   115.1560       2.0           NaN     running_avg            1.5375
# 58   116.0810       0.0           NaN    button_press                 2
# 59   117.1560       2.0           NaN     running_avg                 2
# 60   119.1560       2.0           NaN     running_avg                 2
# 61   121.1560       2.0           NaN     running_avg           1.77245
# 62   122.7009       0.0           NaN    button_press                 1
# 63   123.1560       2.0           NaN     running_avg                 1
# 64   125.1560       2.0           NaN     running_avg                 1
# 65   127.1560       2.0           NaN     running_avg                 1
# 66   129.1560       2.0           NaN     running_avg                 1
# 67   131.1560       1.0           NaN     running_avg                 1
# 68   137.3615      40.0  circle_block   block_summary               NaN
# 69   137.3615       0.0           NaN  default_rating                 5
# 70   137.3615       4.0           NaN     running_avg           5.63105
# 71   138.8158       0.0           NaN    button_press                 6
# 72   141.3400       0.0           NaN    button_press                 5
# 73   141.3615       4.0           NaN     running_avg                 5
# 74   145.3615       4.0           NaN     running_avg           6.49902
# 75   146.1712       0.0           NaN    button_press                 6
# 76   146.5557       0.0           NaN    button_press                 7
# 77   149.3615       4.0           NaN     running_avg            7.8113
# 78   150.1163       0.0           NaN    button_press                 8
# 79   153.3615       4.0           NaN     running_avg            8.7038
# 80   154.5463       0.0           NaN    button_press                 9
# 81   157.3615       4.0           NaN     running_avg            7.8408
# 82   158.6586       0.0           NaN    button_press                 8
# 83   159.4276       0.0           NaN    button_press                 7
# 208  383.1645       0.0           NaN    button_press                 6
# 209  386.6985       4.0           NaN     running_avg           5.05682
# 210  386.9258       0.0           NaN    button_press                 5
# 211  390.6985       4.0           NaN     running_avg            5.8315
# 212  391.3725       0.0           NaN    button_press                 6
# 213  394.6985       4.0           NaN     running_avg           7.59433
# 214  395.3678       0.0           NaN    button_press                 7
# 215  395.6519       0.0           NaN    button_press                 8
# 216  398.6985       4.0           NaN     running_avg           8.83805
# 217  399.3463       0.0           NaN    button_press                 9
# 218  402.6985       4.0           NaN     running_avg                 9
# 220  411.8505     130.0      EA_block   block_summary               NaN
# 221  411.8505       0.0           NaN  default_rating                 5
# 219  411.8505       2.0           NaN     running_avg            3.0166
# 222  411.8671       0.0           NaN    button_press                 3
# 223  413.8505       2.0           NaN     running_avg                 3
# 224  415.8505       2.0           NaN     running_avg                 3
# 225  417.8505       2.0           NaN     running_avg                 3
# 226  419.8505       2.0           NaN     running_avg                 3
# 227  421.8505       2.0           NaN     running_avg                 3
# 228  423.8505       2.0           NaN     running_avg           3.53065
# 229  424.7892       0.0           NaN    button_press                 4
# 230  425.8505       2.0           NaN     running_avg                 4
# 231  427.8505       2.0           NaN     running_avg            3.6676
# 232  429.1857       0.0           NaN    button_press                 3
# 233  429.8505       2.0           NaN     running_avg                 3
# 234  431.8505       2.0           NaN     running_avg                 3
# 235  433.8505       2.0           NaN     running_avg                 3
# 236  435.8505       2.0           NaN     running_avg                 3
# 237  437.8505       2.0           NaN     running_avg                 3
# 238  439.8505       2.0           NaN     running_avg                 3
# 239  441.8505       2.0           NaN     running_avg                 3
# 240  443.8505       2.0           NaN     running_avg                 3
# 241  445.8505       2.0           NaN     running_avg                 3
# 242  447.8505       2.0           NaN     running_avg                 3
# 243  449.8505       2.0           NaN     running_avg                 3
# 244  451.8505       2.0           NaN     running_avg                 3
# 245  453.8505       2.0           NaN     running_avg                 3
# 246  455.8505       2.0           NaN     running_avg                 3
# 247  457.8505       2.0           NaN     running_avg                 3
# 248  458.0723       0.0           NaN    button_press                 2
# 249  459.8505       2.0           NaN     running_avg                 3
# 250  461.8505       2.0           NaN     running_avg                 3
# 251  463.8505       2.0           NaN     running_avg                 3
# 252  465.8505       2.0           NaN     running_avg                 3
# 253  467.8505       2.0           NaN     running_avg                 3
# 254  469.8505       2.0           NaN     running_avg                 3
# 255  471.8505       2.0           NaN     running_avg                 3
# 256  473.8505       2.0           NaN     running_avg                 3
# 257  475.8505       2.0           NaN     running_avg                 3
# 258  477.8505       2.0           NaN     running_avg                 3
# 259  479.8505       2.0           NaN     running_avg                 3
# 260  481.8505       2.0           NaN     running_avg                 3
# 261  483.8505       2.0           NaN     running_avg                 3
# 262  485.8505       2.0           NaN     running_avg                 3
# 263  487.8505       2.0           NaN     running_avg                 3
# 264  489.8505       2.0           NaN     running_avg                 3
# 265  491.8505       2.0           NaN     running_avg                 3
# 266  493.8505       2.0           NaN     running_avg                 3
# 267  495.8505       2.0           NaN     running_avg                 3
# 268  497.8505       2.0           NaN     running_avg                 3
# 269  499.8505       2.0           NaN     running_avg                 3
# 270  501.8505       2.0           NaN     running_avg                 3
# 271  503.8505       2.0           NaN     running_avg                 3
# 272  505.8505       2.0           NaN     running_avg                 3
# 273  507.8505       2.0           NaN     running_avg                 3
# 274  509.8505       2.0           NaN     running_avg                 3
# 275  511.8505       2.0           NaN     running_avg                 3
# 276  513.8505       2.0           NaN     running_avg                 3
# 277  515.8505       2.0           NaN     running_avg                 3
# 278  517.8505       2.0           NaN     running_avg                 3
# 279  519.8505       2.0           NaN     running_avg                 3
# 280  521.8505       2.0           NaN     running_avg                 3
# 281  523.8505       2.0           NaN     running_avg                 3
# 282  525.8505       2.0           NaN     running_avg                 3
# 283  527.8505       2.0           NaN     running_avg                 3
# 284  529.8505       2.0           NaN     running_avg                 3
# 285  531.8505       2.0           NaN     running_avg                 3
# 286  533.8505       2.0           NaN     running_avg                 3
# 287  535.8505       2.0           NaN     running_avg                 3
# 288  537.8505       2.0           NaN     running_avg                 3
# 289  539.8505       2.0           NaN     running_avg                 3
#
#      gold_std  block_score  n_button_press   stim_file
# 0         NaN     0.797046             6.0    HR_1_sad
# 1         NaN          NaN             NaN    HR_1_sad
# 2      5.0000          NaN             NaN    HR_1_sad
# 3      5.0000          NaN             NaN    HR_1_sad
# 4      5.0000          NaN             NaN    HR_1_sad
# 5      5.0000          NaN             NaN    HR_1_sad
# 6      5.0000          NaN             NaN    HR_1_sad
# 7      5.0000          NaN             NaN    HR_1_sad
# 8         NaN          NaN             NaN    HR_1_sad
# 9      3.5855          NaN             NaN    HR_1_sad
# 10     3.0000          NaN             NaN    HR_1_sad
# 11        NaN          NaN             NaN    HR_1_sad
# 12     3.0000          NaN             NaN    HR_1_sad
# 13     3.0000          NaN             NaN    HR_1_sad
# 14     3.0000          NaN             NaN    HR_1_sad
# 15     3.0000          NaN             NaN    HR_1_sad
# 16     2.6085          NaN             NaN    HR_1_sad
# 17     2.0000          NaN             NaN    HR_1_sad
# 18     2.0000          NaN             NaN    HR_1_sad
# 19     2.0000          NaN             NaN    HR_1_sad
# 20     2.0000          NaN             NaN    HR_1_sad
# 21     2.0000          NaN             NaN    HR_1_sad
# 22     2.0000          NaN             NaN    HR_1_sad
# 23     2.0000          NaN             NaN    HR_1_sad
# 24     2.0000          NaN             NaN    HR_1_sad
# 25     2.0000          NaN             NaN    HR_1_sad
# 26     2.0000          NaN             NaN    HR_1_sad
# 27     2.0000          NaN             NaN    HR_1_sad
# 28     2.0000          NaN             NaN    HR_1_sad
# 29     2.0000          NaN             NaN    HR_1_sad
# 30     2.0000          NaN             NaN    HR_1_sad
# 31     2.0000          NaN             NaN    HR_1_sad
# 32     2.0000          NaN             NaN    HR_1_sad
# 33     2.0000          NaN             NaN    HR_1_sad
# 34     2.0000          NaN             NaN    HR_1_sad
# 35     2.0000          NaN             NaN    HR_1_sad
# 36        NaN          NaN             NaN    HR_1_sad
# 37     2.0000          NaN             NaN    HR_1_sad
# 38     2.0000          NaN             NaN    HR_1_sad
# 39     2.0000          NaN             NaN    HR_1_sad
# 40     2.0000          NaN             NaN    HR_1_sad
# 41     2.0000          NaN             NaN    HR_1_sad
# 42     2.0000          NaN             NaN    HR_1_sad
# 43     2.0000          NaN             NaN    HR_1_sad
# 44     2.0000          NaN             NaN    HR_1_sad
# 45     2.0000          NaN             NaN    HR_1_sad
# 46     2.0000          NaN             NaN    HR_1_sad
# 47     2.0000          NaN             NaN    HR_1_sad
# 48     2.0000          NaN             NaN    HR_1_sad
# 49     2.0000          NaN             NaN    HR_1_sad
# 50     2.0000          NaN             NaN    HR_1_sad
# 51     2.0000          NaN             NaN    HR_1_sad
# 52     2.0000          NaN             NaN    HR_1_sad
# 53     2.0000          NaN             NaN    HR_1_sad
# 54     2.0000          NaN             NaN    HR_1_sad
# 55     2.0000          NaN             NaN    HR_1_sad
# 56        NaN          NaN             NaN    HR_1_sad
# 57     1.1125          NaN             NaN    HR_1_sad
# 58        NaN          NaN             NaN    HR_1_sad
# 59     1.0000          NaN             NaN    HR_1_sad
# 60     1.0000          NaN             NaN    HR_1_sad
# 61     1.0000          NaN             NaN    HR_1_sad
# 62        NaN          NaN             NaN    HR_1_sad
# 63     1.0000          NaN             NaN    HR_1_sad
# 64     1.0000          NaN             NaN    HR_1_sad
# 65     1.2060          NaN             NaN    HR_1_sad
# 66     3.0000          NaN             NaN    HR_1_sad
# 67     3.0000          NaN             NaN    HR_1_sad
# 68        NaN     0.948115            14.0    circles7
# 69        NaN          NaN             NaN    circles7
# 70     5.0000          NaN             NaN    circles7
# 71        NaN          NaN             NaN    circles7
# 72        NaN          NaN             NaN    circles7
# 73     3.0000          NaN             NaN    circles7
# 74     6.0000          NaN             NaN    circles7
# 75        NaN          NaN             NaN    circles7
# 76        NaN          NaN             NaN    circles7
# 77     8.0000          NaN             NaN    circles7
# 78        NaN          NaN             NaN    circles7
# 79     9.0000          NaN             NaN    circles7
# 80        NaN          NaN             NaN    circles7
# 81     7.0000          NaN             NaN    circles7
# 82        NaN          NaN             NaN    circles7
# 83        NaN          NaN             NaN    circles7
# 84     4.0000          NaN             NaN    circles7
# 85        NaN          NaN             NaN    circles7
# 86        NaN          NaN             NaN    circles7
# 87     6.0000          NaN             NaN    circles7
# 88        NaN          NaN             NaN    circles7
# 89        NaN          NaN             NaN    circles7
# 90     7.0000          NaN             NaN    circles7
# 91     9.0000          NaN             NaN    circles7
# 92        NaN          NaN             NaN    circles7
# 93        NaN          NaN             NaN    circles7
# 96        NaN    -0.900160             3.0  TA_6_anger
# 95        NaN          NaN             NaN    circles7
# 94     5.0000          NaN             NaN    circles7
# 97        NaN          NaN             NaN  TA_6_anger
# 98     5.0000          NaN             NaN  TA_6_anger
# 99     5.0000          NaN             NaN  TA_6_anger
# 100    5.0000          NaN             NaN  TA_6_anger
# 101    5.0000          NaN             NaN  TA_6_anger
# 102    5.0000          NaN             NaN  TA_6_anger
# 103    5.0000          NaN             NaN  TA_6_anger
# 104    5.0000          NaN             NaN  TA_6_anger
# 105    5.0000          NaN             NaN  TA_6_anger
# 106    5.0000          NaN             NaN  TA_6_anger
