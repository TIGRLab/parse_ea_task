# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 400) ##REMOVE IN SCRIPT

# %%
def read_in_logfile(path):
    log_file=pd.read_csv(path, sep='\t', skiprows=3)

    time_to_subtract=int(log_file.Time[log.Code=='MRI_start'])

    log_file.Time=log_file.Time -time_to_subtract
    return log_file

def get_blocks(log,vid_info):
    #identifies the video trial types (as opposed to button press events etc)
    mask = ["vid" in log['Code'][i] for i in range(0,log.shape[0])]
    #this isnt totally right lol
    #creates the dataframe with onset times and event types
    df = pd.DataFrame({'onset':log.loc[mask]['Time'], 
                  'trial_type':log.loc[mask]['Event Type'], 
                  'movie_name':log.loc[mask]['Code']})
        
    #adds trial type info
    df['trial_type']=df['movie_name'].apply(lambda x: "circle_block" if "cvid" in x else "EA_block")

    #add durations and convert them into the units here? ms??
    df['duration']=df['movie_name'].apply(lambda x: int(vid_info[x]['duration'])*10000 if x in vid_info else "n/a")

    #I don't actually know what the stim files are called for the circle ones - also these names aren't exact,gotta figure out a way to get exact file names
    df['stim_file']=df['movie_name'].apply(lambda x: vid_info[x]['stim_file'] if x in vid_info else "n/a") 
    
    
    df['end']=df['onset']+df['duration']

        
    return(df)


    
def format_vid_info(vid):
    vid.columns = map(str.lower, vid.columns)
    vid = vid.rename(index={0:"stim_file", 1:"duration"})
    vid = vid.to_dict()
    return(vid)


def read_in_standard(timing_path):
    df = pd.read_csv(timing_path).astype(str)
    df.columns = map(str.lower, df.columns)
    df_dict = df.drop([0,0]).reset_index(drop=True).to_dict(orient='list') #drops the video name
    return(df_dict)

def get_series_standard(gold_standard, block_name):
    
    return([float(x) for x in ratings_dict[block_name] if x != 'nan'])


def get_ratings(log):
    #the times in this row are EXTREMELY close to the other times. This isn't EEG, I think we're prolly ok
    rating_mask = ["rating" in log['Code'][i] for i in range(0,log.shape[0])]  
    #RT_mask=  ["Response" in log['Event Type'][i] and log['Code'][i]!="101"  for i in range(0,log.shape[0]-1)]  #this is from when i was doing it the response time way, but idk how i feel abt that

    #so now this grabs the timestamp from the row before (which is the actual onset) then applies the rating mask to that list of values
    #df = pd.DataFrame({'onset':log['Time'].shift(1).loc[rating_mask].values, 'participant_rating':log.loc[rating_mask]['Code'].values, 'event_type':'button_press', 'duration':0})    
    
    
    #switching it to not be from the row before because if it has a vid tag before it then it will get the wrong onset number
    df = pd.DataFrame({'onset':log['Time'].loc[rating_mask].values, 'participant_rating':log.loc[rating_mask]['Code'].values, 'event_type':'button_press', 'duration':0})    
    #this pretty much fixes it except for the vid_thing - one thing I could do is just get rid of the vid_ rows!! TODO later.
    
    #gets rating substring from participant numbers
    df['participant_rating'] = df['participant_rating'].str.strip().str[-1] #do i have to add a .astype to this?
    
    #TODO: probably remove this from this function and rewrite it in the place where i combine the ratings and block info
    #df['rating_duration'] = df.onset.shift(-1)-df.onset #this isnt totally correct bc of the stuff.

    return(df)


def combine_dfs(blocks,ratings):
    combo=blocks.append(ratings).sort_values("onset").reset_index(drop=True)

    mask = pd.notnull(combo['trial_type'])
    #combo['end_time']=combo['onset']-combo['onset'].shift(1)

    combo['rating_duration']=combo['onset'].shift(-1)-combo['onset'].where(mask==False) #hmm but how do i make the ones in the end of the row? because those actually should calculate from block_end, not from the beginning of the next guy...
    #this one is tricky!!

    block_start_locs=combo[mask].index.values

    #so one way to do this would be to make durations visible everywhere

    #can i do for i in block_start_locs

    #yay! fixes the rating for the last button press of a series!
    #gives a SettingWithCopy warning
    #TODO: fix this lol
    #this ends up not assigning a value for the final button press - there must be a more elegant way to do all this
    for i in range(len(block_start_locs)):
        if block_start_locs[i] != 0:
            #maybe i should calculate these vars separately for clarity
            combo.rating_duration[block_start_locs[i]-1]=combo.end[block_start_locs[i-1]] - combo.onset[block_start_locs[i]-1]

            
#adds rows that contain the 5 second at the beginning default value
    for i in block_start_locs:
            new_row={'onset':combo.onset[i],
            'rating_duration':combo.onset[i+1] - combo.onset[i],
            'event_type':'default_rating',
            'duration':0,
            'participant_rating':5}
            combo=combo.append(new_row,ignore_index=True)
        
    combo=combo.sort_values("onset").reset_index(drop=True)

    return(combo)



def block_scores(ratings_dict,combo):
    list_of_rows=[]
    summary_vals = {}
    mask = pd.notnull(combo['trial_type']) #selects the beginning of trials/trial headers #i feel like im recalculating that in lots of places, seems bad maybe
    block_start_locs=combo[mask].index.values #i could just append the end to that
    block_start_locs= np.append(block_start_locs, combo.tail(1).index.values, axis=None)
    
    for idx in range(1, len(block_start_locs)):

        block_start=combo.onset[block_start_locs[idx-1]]
        block_end=combo.end[block_start_locs[idx-1]]

        #selects the rows between the start and the end that contain button presses
        #should just change this to select the rows, idk why not lol
        block = combo.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.event_type)]#between is inclusive by default
        block_name=combo.movie_name.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.movie_name)].reset_index(drop=True).astype(str).get(0)
        
        ###############################################################################################
        gold=get_series_standard(ratings_dict,block_name)

        interval = np.arange(combo.onset[block_start_locs[idx-1]], combo.end[block_start_locs[idx-1]],step=20000) #AAA oh no this only applies to the vid not the cvid (put a conditional here)
        if len(gold) < len(interval):
            interval=interval[:len(gold)]
            #todo: insert a warning that the participant ratings were truncated
            #also this doesnt account for a situation where there are less ratings than the gold standard
            #which could absolutely be a thing if the task was truncated
            #gold.extend([gold[-1]]*(len(interval)-len(gold)))

        interval=np.append(interval, block_end) #this is to append for the remaining fraction of a second - maybe i dont need to do this

        #why is this not doing what it is supposed to do.
        #these ifs are NOT working
        two_s_avg=[]
        for x in range(len(interval)-1):
            start=interval[x]
            end=interval[x+1]
            #things that start within the time interval plus the one that starts during the time interval
            sub_block= block[block['onset'].between(start,end) | block['onset'].between(start,end).shift(-1)]
            block_length=end-start
            if len(sub_block) !=0: 
                ratings=[]
                last_val=sub_block.participant_rating.iloc[[-1]]
                for index, row in sub_block.iterrows():
                    #for rows that are in the thing
                    if (row.onset < start): #and (row.onset+row.duration)>start: #what's the best order to do these conditionals in?
                        #if (row.onset+row.duration)>start: # this is just to be safe i guess, gonna see what happens if i comment it out
                        numerator=(row.onset+row.rating_duration)-start
                    else:#if row.onset>=start and row.onset<end: #ooo should i do row.onset<end for everything??
                        if (row.onset+row.rating_duration) <= end:
                            numerator=row.rating_duration
                        elif (row.onset+row.rating_duration) > end: 
                            numerator = end - row.onset
                        else:
                            numerator=9999999
                    last_row=row.participant_rating
                    #okay so i want to change this to actually create the beginnings of an important row in our df!
                    ratings.append({'start':start,'end':end,'row_time':row.rating_duration, 'row_start': row.onset, 'block_length':block_length,'rating':row.participant_rating, 'time_held':numerator})#, 'start': start, 'end':end})
                    nums=[float(d['rating']) for d in ratings]
                    times=[float(d['time_held'])/block_length for d in ratings]
                    avg=np.sum(np.multiply(nums,times))
            else:
                avg=last_row

            #okay so i want to change this to actually create the beginnings of an important row in our df!
            two_s_avg.append(float(avg))
            #list_of_rows.append({'event_type':"two_sec_avg",'block_name':block_name, 'participant_value':float(avg),'onset':start,'duration':end-start, 'gold_std': gold[x]})
            list_of_rows.append({'event_type':"two_sec_avg", 'participant_value':float(avg),'onset':start,'duration':end-start, 'gold_std': gold[x]})
            #removed block_name from above
        block_score=np.corrcoef(gold,two_s_avg)[1][0] 
        key=str(block_name)
        summary_vals.update({key:{'block_score':block_score,'onset':block_start,'duration':block_end-block_start}})
        #summary_vals.append(block_name:{'block_score':block_score,'block_name':block_name,'onset':block_start,'duration':block_end-block_start}) #i can probably not recalculate duration, just gotta remember how
    
    return(list_of_rows,summary_vals)

# %%
#Reads in the log, skipping the first three preamble lines

log = read_in_logfile('/projects/gherman/Experimenting_notebooks/SPN01_CMH_0001-UCLAEmpAcc_part1.log')
vid_in = pd.read_csv('EA-vid-lengths.csv')

vid_info = format_vid_info(vid_in)
blocks = get_blocks(log, vid_info)
ratings = get_ratings(log)

#add the ratings and the block values together, then sort them and make the index numbers sequential
combo=combine_dfs(blocks,ratings)

ratings_dict= read_in_standard('EA-timing.csv')

two_s_chunks,scores= block_scores(ratings_dict,combo) #okay so i need to fix the naming here 

combo['block_score']=np.nan
#combo.ix[pd.notnull(combo.trial_type), 'block_score']=

#df[df.index.isin(a_list) & df.a_col.isnull()]

combo = combo.append(two_s_chunks).sort_values("onset").reset_index(drop=True) #this needs to be fixed etc #need to sort according to name too...

test = combo.ix[pd.notnull(combo.trial_type)]

for index, row in test.iterrows():
    combo.block_score.ix[index]=scores[row['movie_name']]['block_score']
    
    
combo
# Out:
# /mnt/tigrlab/archive/code/python_2.7.13_packages_01/lib/python2.7/site-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /mnt/tigrlab/archive/code/python_2.7.13_packages_01/lib/python2.7/site-packages/ipykernel_launcher.py:129: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      block_score   duration        end      event_type  gold_std movie_name  \
# 0       0.441424  1700000.0  2881540.0             NaN       NaN      vid_4
# 1            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 2            NaN        0.0        NaN  default_rating       NaN        NaN
# 3            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 4            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 5            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 6            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 7            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 8            NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 9            NaN        0.0        NaN    button_press       NaN        NaN
# 10           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 11           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 12           NaN        0.0        NaN    button_press       NaN        NaN
# 13           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 14           NaN        0.0        NaN    button_press       NaN        NaN
# 15           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 16           NaN        0.0        NaN    button_press       NaN        NaN
# 17           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 18           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 19           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 20           NaN        0.0        NaN    button_press       NaN        NaN
# 21           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 22           NaN        0.0        NaN    button_press       NaN        NaN
# 23           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 24           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 25           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 26           NaN        0.0        NaN    button_press       NaN        NaN
# 27           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 28           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 29           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 30           NaN        0.0        NaN    button_press       NaN        NaN
# 31           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 32           NaN        0.0        NaN    button_press       NaN        NaN
# 33           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 34           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 35           NaN        0.0        NaN    button_press       NaN        NaN
# 36           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 37           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 38           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 39           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 40           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 41           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 42           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 43           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 44           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 45           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 46           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 47           NaN    20000.0        NaN     two_sec_avg    4.8995        NaN
# 48           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 49           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 50           NaN    20000.0        NaN     two_sec_avg    5.6150        NaN
# 51           NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 52           NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 53           NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 54           NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 55           NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 56           NaN    20000.0        NaN     two_sec_avg    6.1205        NaN
# 57           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 58           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 59           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 60           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 61           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 62           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 63           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 64           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 65           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 66           NaN    20000.0        NaN     two_sec_avg    7.0850        NaN
# 67           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 68           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 69           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 70           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 71           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 72           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 73           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 74           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 75           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 76           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 77           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 78           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 79           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 80           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 81           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 82           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 83           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 84           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 85           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 86           NaN        0.0        NaN    button_press       NaN        NaN
# 87           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 88           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 89           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 90           NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 91           NaN    20000.0        NaN     two_sec_avg    7.3205        NaN
# 92           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 93           NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 94           NaN    80000.0        NaN     two_sec_avg    7.0000        NaN
# 95           NaN        0.0        NaN    button_press       NaN        NaN
# 96           NaN        0.0        NaN  default_rating       NaN        NaN
# 97      0.170853   400000.0  3338805.0             NaN       NaN     cvid_1
# 98           NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 99           NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 100          NaN        0.0        NaN    button_press       NaN        NaN
# 101          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 102          NaN        0.0        NaN    button_press       NaN        NaN
# 103          NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 104          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 105          NaN        0.0        NaN    button_press       NaN        NaN
# 106          NaN        0.0        NaN    button_press       NaN        NaN
# 107          NaN        0.0        NaN    button_press       NaN        NaN
# 108          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 109          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 110          NaN        0.0        NaN    button_press       NaN        NaN
# 111          NaN        0.0        NaN    button_press       NaN        NaN
# 112          NaN        0.0        NaN    button_press       NaN        NaN
# 113          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 114          NaN        0.0        NaN    button_press       NaN        NaN
# 115          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 116          NaN        0.0        NaN    button_press       NaN        NaN
# 117          NaN   220000.0        NaN     two_sec_avg    7.0000        NaN
# 118          NaN        0.0        NaN    button_press       NaN        NaN
# 119          NaN        0.0        NaN    button_press       NaN        NaN
# 120          NaN        0.0        NaN    button_press       NaN        NaN
# 121          NaN        0.0        NaN    button_press       NaN        NaN
# 122          NaN        0.0        NaN    button_press       NaN        NaN
# 123          NaN        0.0        NaN    button_press       NaN        NaN
# 124          NaN        0.0        NaN    button_press       NaN        NaN
# 125          NaN        0.0        NaN    button_press       NaN        NaN
# 126          NaN        0.0        NaN    button_press       NaN        NaN
# 127          NaN        0.0        NaN    button_press       NaN        NaN
# 128          NaN        0.0        NaN    button_press       NaN        NaN
# 129          NaN        0.0        NaN    button_press       NaN        NaN
# 130          NaN        0.0        NaN    button_press       NaN        NaN
# 131          NaN        0.0        NaN    button_press       NaN        NaN
# 132          NaN        0.0        NaN    button_press       NaN        NaN
# 133          NaN        0.0        NaN    button_press       NaN        NaN
# 134          NaN        0.0        NaN    button_press       NaN        NaN
# 135          NaN        0.0        NaN    button_press       NaN        NaN
# 136     0.569680  1460000.0  4850491.0             NaN       NaN      vid_2
# 137          NaN        0.0        NaN  default_rating       NaN        NaN
# 138          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 139          NaN        0.0        NaN    button_press       NaN        NaN
# 140          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 141          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 142          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 143          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 144          NaN        0.0        NaN    button_press       NaN        NaN
# 145          NaN        0.0        NaN    button_press       NaN        NaN
# 146          NaN    20000.0        NaN     two_sec_avg    7.7530        NaN
# 147          NaN    20000.0        NaN     two_sec_avg    8.1890        NaN
# 148          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 149          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 150          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 151          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 152          NaN    20000.0        NaN     two_sec_avg    7.9105        NaN
# 153          NaN    20000.0        NaN     two_sec_avg    3.7305        NaN
# 154          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 155          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 156          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 157          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 158          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 159          NaN    20000.0        NaN     two_sec_avg    2.5260        NaN
# 160          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 161          NaN        0.0        NaN    button_press       NaN        NaN
# 162          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 163          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 164          NaN        0.0        NaN    button_press       NaN        NaN
# 165          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 166          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 167          NaN    20000.0        NaN     two_sec_avg    5.0995        NaN
# 168          NaN    20000.0        NaN     two_sec_avg    7.1275        NaN
# 169          NaN    20000.0        NaN     two_sec_avg    7.8240        NaN
# 170          NaN    20000.0        NaN     two_sec_avg    3.3210        NaN
# 171          NaN        0.0        NaN    button_press       NaN        NaN
# 172          NaN        0.0        NaN    button_press       NaN        NaN
# 173          NaN        0.0        NaN    button_press       NaN        NaN
# 174          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 175          NaN        0.0        NaN    button_press       NaN        NaN
# 176          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 177          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 178          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 179          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 180          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 181          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 182          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 183          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 184          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 185          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 186          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 187          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 188          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 189          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 190          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 191          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 192          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 193          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 194          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 195          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 196          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 197          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 198          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 199          NaN    20000.0        NaN     two_sec_avg    2.5285        NaN
# 200          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 201          NaN        0.0        NaN    button_press       NaN        NaN
# 202          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 203          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 204          NaN        0.0        NaN    button_press       NaN        NaN
# 205          NaN        0.0        NaN    button_press       NaN        NaN
# 206          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 207          NaN        0.0        NaN    button_press       NaN        NaN
# 208          NaN        0.0        NaN    button_press       NaN        NaN
# 209          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 210          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 211          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 212          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 213          NaN    20000.0        NaN     two_sec_avg    3.4915        NaN
# 214          NaN    20000.0        NaN     two_sec_avg    6.4900        NaN
# 215          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 216          NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 217          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 218          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 219          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 220          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 221          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 222          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 223          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 224          NaN        0.0        NaN    button_press       NaN        NaN
# 225          NaN        0.0        NaN    button_press       NaN        NaN
# 226          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 227     0.578682   400000.0  5302187.0             NaN       NaN     cvid_2
# 228          NaN        0.0        NaN  default_rating       NaN        NaN
# 229          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 230          NaN        0.0        NaN    button_press       NaN        NaN
# 231          NaN        0.0        NaN    button_press       NaN        NaN
# 232          NaN        0.0        NaN    button_press       NaN        NaN
# 233          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 234          NaN        0.0        NaN    button_press       NaN        NaN
# 235          NaN    20000.0        NaN     two_sec_avg    3.0000        NaN
# 236          NaN        0.0        NaN    button_press       NaN        NaN
# 237          NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 238          NaN        0.0        NaN    button_press       NaN        NaN
# 239          NaN    20000.0        NaN     two_sec_avg    1.0000        NaN
# 240          NaN        0.0        NaN    button_press       NaN        NaN
# 241          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 242          NaN    20000.0        NaN     two_sec_avg    4.0000        NaN
# 243          NaN        0.0        NaN    button_press       NaN        NaN
# 244          NaN    20000.0        NaN     two_sec_avg    2.0000        NaN
# 245          NaN        0.0        NaN    button_press       NaN        NaN
# 246          NaN    20000.0        NaN     two_sec_avg    1.0000        NaN
# 247          NaN        0.0        NaN    button_press       NaN        NaN
# 248          NaN        0.0        NaN    button_press       NaN        NaN
# 249          NaN   220000.0        NaN     two_sec_avg    3.0000        NaN
# 250          NaN        0.0        NaN    button_press       NaN        NaN
# 251          NaN        0.0        NaN    button_press       NaN        NaN
# 252          NaN        0.0        NaN    button_press       NaN        NaN
# 253          NaN        0.0        NaN    button_press       NaN        NaN
# 254          NaN        0.0        NaN    button_press       NaN        NaN
# 255          NaN        0.0        NaN    button_press       NaN        NaN
# 256          NaN        0.0        NaN    button_press       NaN        NaN
# 257          NaN        0.0        NaN    button_press       NaN        NaN
# 258          NaN        0.0        NaN    button_press       NaN        NaN
# 259          NaN        0.0        NaN    button_press       NaN        NaN
# 260          NaN        0.0        NaN    button_press       NaN        NaN
# 261          NaN        0.0        NaN    button_press       NaN        NaN
# 262          NaN        0.0        NaN    button_press       NaN        NaN
# 263          NaN        0.0        NaN    button_press       NaN        NaN
# 264    -0.011163  1110000.0  6463670.0             NaN       NaN      vid_5
# 265          NaN        0.0        NaN  default_rating       NaN        NaN
# 266          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 267          NaN        0.0        NaN    button_press       NaN        NaN
# 268          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 269          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 270          NaN        0.0        NaN    button_press       NaN        NaN
# 271          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 272          NaN        0.0        NaN    button_press       NaN        NaN
# 273          NaN    20000.0        NaN     two_sec_avg    5.0000        NaN
# 274          NaN        0.0        NaN    button_press       NaN        NaN
# 275          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 276          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 277          NaN        0.0        NaN    button_press       NaN        NaN
# 278          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 279          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 280          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 281          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 282          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 283          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 284          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 285          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 286          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 287          NaN    20000.0        NaN     two_sec_avg    6.0000        NaN
# 288          NaN    20000.0        NaN     two_sec_avg    6.0205        NaN
# 289          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 290          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 291          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 292          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 293          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 294          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 295          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 296          NaN    20000.0        NaN     two_sec_avg    7.0000        NaN
# 297          NaN    20000.0        NaN     two_sec_avg    7.5815        NaN
# 298          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 299          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 300          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 301          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 302          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 303          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 304          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 305          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 306          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 307          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 308          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 309          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 310          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 311          NaN    20000.0        NaN     two_sec_avg    8.0000        NaN
# 312          NaN    20000.0        NaN     two_sec_avg    8.3090        NaN
# 313          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 314          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 315          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 316          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 317          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 318          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 319          NaN        0.0        NaN    button_press       NaN        NaN
# 320          NaN        0.0        NaN    button_press       NaN        NaN
# 321          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 322          NaN        0.0        NaN    button_press       NaN        NaN
# 323          NaN        0.0        NaN    button_press       NaN        NaN
# 324          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 325          NaN        0.0        NaN    button_press       NaN        NaN
# 326          NaN        0.0        NaN    button_press       NaN        NaN
# 327          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 328          NaN        0.0        NaN    button_press       NaN        NaN
# 329          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 330          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 331          NaN    20000.0        NaN     two_sec_avg    9.0000        NaN
# 332          NaN    30000.0        NaN     two_sec_avg    9.0000        NaN
#
#          onset participant_rating  participant_value  rating_duration  \
# 0    1181540.0                NaN                NaN              NaN
# 1    1181540.0                NaN           5.000000              NaN
# 2    1181540.0                  5                NaN         125710.0
# 3    1201540.0                NaN           5.000000              NaN
# 4    1221540.0                NaN           5.000000              NaN
# 5    1241540.0                NaN           5.000000              NaN
# 6    1261540.0                NaN           5.000000              NaN
# 7    1281540.0                NaN           5.000000              NaN
# 8    1301540.0                NaN           5.714500              NaN
# 9    1307250.0                  6                NaN          49314.0
# 10   1321540.0                NaN           6.000000              NaN
# 11   1341540.0                NaN           5.751200              NaN
# 12   1356564.0                  5                NaN          12705.0
# 13   1361540.0                NaN           4.386450              NaN
# 14   1369269.0                  4                NaN          18890.0
# 15   1381540.0                NaN           3.330950              NaN
# 16   1388159.0                  3                NaN          58509.0
# 17   1401540.0                NaN           3.000000              NaN
# 18   1421540.0                NaN           3.000000              NaN
# 19   1441540.0                NaN           3.743600              NaN
# 20   1446668.0                  4                NaN          25576.0
# 21   1461540.0                NaN           4.464800              NaN
# 22   1472244.0                  5                NaN          59679.0
# 23   1481540.0                NaN           5.000000              NaN
# 24   1501540.0                NaN           5.000000              NaN
# 25   1521540.0                NaN           5.480850              NaN
# 26   1531923.0                  6                NaN          64360.0
# 27   1541540.0                NaN           6.000000              NaN
# 28   1561540.0                NaN           6.000000              NaN
# 29   1581540.0                NaN           6.262850              NaN
# 30   1596283.0                  7                NaN          18890.0
# 31   1601540.0                NaN           7.318350              NaN
# 32   1615173.0                  8                NaN          28752.0
# 33   1621540.0                NaN           8.000000              NaN
# 34   1641540.0                NaN           8.880750              NaN
# 35   1643925.0                  9                NaN        1017047.0
# 36   1661540.0                NaN           9.000000              NaN
# 37   1681540.0                NaN           9.000000              NaN
# 38   1701540.0                NaN           9.000000              NaN
# 39   1721540.0                NaN           9.000000              NaN
# 40   1741540.0                NaN           9.000000              NaN
# 41   1761540.0                NaN           9.000000              NaN
# 42   1781540.0                NaN           9.000000              NaN
# 43   1801540.0                NaN           9.000000              NaN
# 44   1821540.0                NaN           9.000000              NaN
# 45   1841540.0                NaN           9.000000              NaN
# 46   1861540.0                NaN           9.000000              NaN
# 47   1881540.0                NaN           9.000000              NaN
# 48   1901540.0                NaN           9.000000              NaN
# 49   1921540.0                NaN           9.000000              NaN
# 50   1941540.0                NaN           9.000000              NaN
# 51   1961540.0                NaN           9.000000              NaN
# 52   1981540.0                NaN           9.000000              NaN
# 53   2001540.0                NaN           9.000000              NaN
# 54   2021540.0                NaN           9.000000              NaN
# 55   2041540.0                NaN           9.000000              NaN
# 56   2061540.0                NaN           9.000000              NaN
# 57   2081540.0                NaN           9.000000              NaN
# 58   2101540.0                NaN           9.000000              NaN
# 59   2121540.0                NaN           9.000000              NaN
# 60   2141540.0                NaN           9.000000              NaN
# 61   2161540.0                NaN           9.000000              NaN
# 62   2181540.0                NaN           9.000000              NaN
# 63   2201540.0                NaN           9.000000              NaN
NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# 5               NaN           NaN
# 6               NaN           NaN
# 7               NaN           NaN
# 8               NaN           NaN
# 9               NaN           NaN
# 10              NaN           NaN
# 11              NaN           NaN
# 12              NaN           NaN
# 13              NaN           NaN
# 14              NaN           NaN
# 15              NaN           NaN
# 16              NaN           NaN
# 17              NaN           NaN
# 18              NaN           NaN
# 19              NaN           NaN
# 20              NaN           NaN
# 21              NaN           NaN
# 22              NaN           NaN
# 23              NaN           NaN
# 24              NaN           NaN
# 25              NaN           NaN
# 26              NaN           NaN
# 27              NaN           NaN
# 28              NaN           NaN
# 29              NaN           NaN
# 30              NaN           NaN
# 31              NaN           NaN
# 32              NaN           NaN
# 33              NaN           NaN
# 34              NaN           NaN
# 35              NaN           NaN
# 36              NaN           NaN
# 37              NaN           NaN
# 38              NaN           NaN
# 39              NaN           NaN
# 40              NaN           NaN
# 41              NaN           NaN
# 42              NaN           NaN
# 43              NaN           NaN
# 44              NaN           NaN
# 45              NaN           NaN
# 46              NaN           NaN
# 47              NaN           NaN
# 48              NaN           NaN
# 49              NaN           NaN
# 50              NaN           NaN
# 51              NaN           NaN
# 52              NaN           NaN
# 53              NaN           NaN
# 54              NaN           NaN
# 55              NaN           NaN
# 56              NaN           NaN
# 57              NaN           NaN
# 58              NaN           NaN
# 59              NaN           NaN
# 60              NaN           NaN
# 61              NaN           NaN
# 62              NaN           NaN
# 63              NaN           NaN
# 64              NaN           NaN
# 65              NaN           NaN
# 66              NaN           NaN
# 67              NaN           NaN
# 68              NaN           NaN
# 69              NaN           NaN
# 70              NaN           NaN
# 71              NaN           NaN
# 72              NaN           NaN
# 73              NaN           NaN
# 74              NaN           NaN
# 75              NaN           NaN
# 76              NaN           NaN
# 77              NaN           NaN
# 78              NaN           NaN
# 79              NaN           NaN
# 80              NaN           NaN
# 81              NaN           NaN
# 82              NaN           NaN
# 83              NaN           NaN
# 84              NaN           NaN
# 85              NaN           NaN
# 86              NaN           NaN
# 87              NaN           NaN
# 88              NaN           NaN
# 89              NaN           NaN
# 90              NaN           NaN
# 91              NaN           NaN
# 92              NaN           NaN
# 93              NaN           NaN
# 94              NaN           NaN
# 95              NaN           NaN
# 96              NaN           NaN
# 97         circles1  circle_block
# 98              NaN           NaN
# 99              NaN           NaN
# 100             NaN           NaN
# 101             NaN           NaN
# 102             NaN           NaN
# 103             NaN           NaN
# 104             NaN           NaN
# 105             NaN           NaN
# 106             NaN           NaN
# 107             NaN           NaN
# 108             NaN           NaN
# 109             NaN           NaN
# 110             NaN           NaN
# 111             NaN           NaN
# 112             NaN           NaN
# 113             NaN           NaN
# 114             NaN           NaN
# 115             NaN           NaN
# 116             NaN           NaN
# 117             NaN           NaN
# 118             NaN           NaN
# 243             NaN           NaN
# 244             NaN           NaN
# 245             NaN           NaN
# 246             NaN           NaN
# 247             NaN           NaN
# 248             NaN           NaN
# 249             NaN           NaN
# 250             NaN           NaN
# 251             NaN           NaN
# 252             NaN           NaN
# 253             NaN           NaN
# 254             NaN           NaN
# 255             NaN           NaN
# 256             NaN           NaN
# 257             NaN           NaN
# 258             NaN           NaN
# 259             NaN           NaN
# 260             NaN           NaN
# 261             NaN           NaN
# 262             NaN           NaN
# 263             NaN           NaN
# 264      TA_2_amuse      EA_block
# 265             NaN           NaN
# 266             NaN           NaN
# 267             NaN           NaN
# 268             NaN           NaN
# 269             NaN           NaN
# 270             NaN           NaN
# 271             NaN           NaN
# 272             NaN           NaN
# 273             NaN           NaN
# 274             NaN           NaN
# 275             NaN           NaN
# 276             NaN           NaN
# 277             NaN           NaN
# 278             NaN           NaN
# 279             NaN           NaN
# 280             NaN           NaN
# 281             NaN           NaN
# 282             NaN           NaN
# 283             NaN           NaN
# 284             NaN           NaN
# 285             NaN           NaN
# 286             NaN           NaN
# 287             NaN           NaN
# 288             NaN           NaN
# 289             NaN           NaN
# 290             NaN           NaN
# 291             NaN           NaN
# 292             NaN           NaN
# 293             NaN           NaN
# 294             NaN           NaN
# 295             NaN           NaN
# 296             NaN           NaN
# 297             NaN           NaN
# 298             NaN           NaN
# 299             NaN           NaN
# 300             NaN           NaN
# 301             NaN           NaN
# 302             NaN           NaN
# 303             NaN           NaN
# 304             NaN           NaN
# 305             NaN           NaN
# 306             NaN           NaN
# 307             NaN           NaN
# 308             NaN           NaN
# 309             NaN           NaN
# 310             NaN           NaN
# 311             NaN           NaN
# 312             NaN           NaN
# 313             NaN           NaN
# 314             NaN           NaN
# 315             NaN           NaN
# 316             NaN           NaN
# 317             NaN           NaN
# 318             NaN           NaN
# 319             NaN           NaN
# 320             NaN           NaN
# 321             NaN           NaN
# 322             NaN           NaN
# 323             NaN           NaN
# 324             NaN           NaN
# 325             NaN           NaN
# 326             NaN           NaN
# 327             NaN           NaN
# 328             NaN           NaN
# 329             NaN           NaN
# 330             NaN           NaN
# 331             NaN           NaN
# 332             NaN           NaN

# %%
#i'm wondering if i should maybe think more carefully about my architecture here in terms of what i need to calculate where.might try to refine this.

# %%
combo.iloc[45:62]

idx=1
block_name=combo.movie_name.iloc[block_start_locs[idx-1]:block_start_locs[idx]][pd.notnull(combo.movie_name)].astype(str).get(0) 
block_name
# Out:
# 'vid_4'

# %%
[gold[-1]]*(len(interval)-len(gold))
# Out:
# [7.0, 7.0, 7.0]

# %%
np.corrcoef(gold,two_s_avg)[1][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-a5064a50085b> in <module>()
# ----> 1 np.corrcoef(gold,two_s_avg)[1][0]
#
# NameError: name 'gold' is not defined

# %%
#ratings,scores=block_scores(ratings_dict,combo)
combo.tail(1).index.values
# Out:
# array([102])

# %%
# Out:
#     movie_name    onset trial_type
# 2        vid_4  1181540      Video
# 28      cvid_1  2938805      Video
# 86       vid_2  3390491      Video
# 118     cvid_2  4902187      Video
# 168      vid_5  5353670      Video
